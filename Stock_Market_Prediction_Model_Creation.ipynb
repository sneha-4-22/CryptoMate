# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install yfinance
import yfinance as yf
import tensorflow as tf
# Out:
# C:\Users\Sneha\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Requirement already satisfied: yfinance in c:\users\sneha\anaconda3\lib\site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\sneha\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sneha\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\sneha\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\sneha\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sneha\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sneha\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sneha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sneha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sneha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sneha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# WARNING:tensorflow:From C:\Users\Sneha\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
start = '2012-01-01'
end = '2022-12-21'
stock = 'GOOG'

data = yf.download(stock, start, end)
# Out:
# C:\Users\Sneha\anaconda3\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2012-01-03  16.262545  16.641375  16.248346  16.573130  16.573130
# 1    2012-01-04  16.563665  16.693678  16.453827  16.644611  16.644611
# 2    2012-01-05  16.491436  16.537264  16.344486  16.413727  16.413727
# 3    2012-01-06  16.417213  16.438385  16.184088  16.189817  16.189817
# 4    2012-01-09  16.102144  16.114599  15.472754  15.503389  15.503389
# ...         ...        ...        ...        ...        ...        ...
# 2756 2022-12-14  95.540001  97.220001  93.940002  95.309998  95.309998
# 2757 2022-12-15  93.540001  94.029999  90.430000  91.199997  91.199997
# 2758 2022-12-16  91.199997  91.750000  90.010002  90.860001  90.860001
# 2759 2022-12-19  90.879997  91.199997  88.925003  89.150002  89.150002
# 2760 2022-12-20  88.730003  89.779999  88.040001  89.629997  89.629997
#
#          Volume
# 0     147611217
# 1     114989399
# 2     131808205
# 3     108119746
# 4     233776981
# ...         ...
# 2756   26452900
# 2757   28298800
# 2758   48485500
# 2759   23020500
# 2760   21976800
#
# [2761 rows x 7 columns]

# %%
ma_100_days = data.Close.rolling(100).mean()

# %%
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r')
plt.plot(data.Close, 'g')
plt.show()

# %%
ma_200_days = data.Close.rolling(200).mean()

# %%
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r')
plt.plot(ma_200_days,'b')
plt.plot(data.Close,'g')
plt.show()

# %%
data.dropna(inplace=True)

# %%
data_train = pd.DataFrame(data.Close[0: int(len(data)*0.80)])
data_test = pd.DataFrame(data.Close[int(len(data)*0.80): len(data)])

# %%
data_train.shape[0]
# Out:
# 2208

# %%
data_test.shape[0]
# Out:
# 553

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_train_scale = scaler.fit_transform(data_train)

# %%
x = []
y = []

for i in range(100, data_train_scale.shape[0]):
    x.append(data_train_scale[i-100:i])
    y.append(data_train_scale[i,0])

# %%
x, y = np.array(x), np.array(y)

# %%
import tensorflow as tf
import keras

from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
               input_shape = ((x.shape[1],1))))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation='relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units =1))
# Out:
# WARNING:tensorflow:From C:\Users\Sneha\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\Sneha\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x,y, epochs = 50, batch_size =32, verbose =1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Sneha\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 66/66 [==============================] - 35s 365ms/step - loss: 0.0381
# Epoch 2/50
# 66/66 [==============================] - 25s 374ms/step - loss: 0.0072
# Epoch 3/50
# 66/66 [==============================] - 23s 347ms/step - loss: 0.0056
# Epoch 4/50
# 66/66 [==============================] - 23s 346ms/step - loss: 0.0048
# Epoch 5/50
# 66/66 [==============================] - 24s 365ms/step - loss: 0.0050
# Epoch 6/50
# 66/66 [==============================] - 23s 354ms/step - loss: 0.0047
# Epoch 7/50
# 66/66 [==============================] - 24s 368ms/step - loss: 0.0047
# Epoch 8/50
# 66/66 [==============================] - 23s 356ms/step - loss: 0.0047
# Epoch 9/50
# 66/66 [==============================] - 24s 358ms/step - loss: 0.0041
# Epoch 10/50
# 66/66 [==============================] - 22s 339ms/step - loss: 0.0037
# Epoch 11/50
# 66/66 [==============================] - 23s 356ms/step - loss: 0.0041
# Epoch 12/50
# 66/66 [==============================] - 23s 352ms/step - loss: 0.0041
# Epoch 13/50
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0038
# Epoch 14/50
# 66/66 [==============================] - 24s 363ms/step - loss: 0.0036
# Epoch 15/50
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0033
# Epoch 16/50
# 66/66 [==============================] - 24s 359ms/step - loss: 0.0031
# Epoch 17/50
# 66/66 [==============================] - 25s 374ms/step - loss: 0.0033
# Epoch 18/50
# 66/66 [==============================] - 24s 361ms/step - loss: 0.0029
# Epoch 19/50
# 66/66 [==============================] - 23s 348ms/step - loss: 0.0030
# Epoch 20/50
# 66/66 [==============================] - 24s 357ms/step - loss: 0.0027
# Epoch 21/50
# 66/66 [==============================] - 23s 350ms/step - loss: 0.0029
# Epoch 22/50
# 66/66 [==============================] - 23s 350ms/step - loss: 0.0028
# Epoch 23/50
# 66/66 [==============================] - 23s 354ms/step - loss: 0.0024
# Epoch 24/50
# 66/66 [==============================] - 23s 355ms/step - loss: 0.0028
# Epoch 25/50
# 66/66 [==============================] - 24s 370ms/step - loss: 0.0027
# Epoch 26/50
# 66/66 [==============================] - 24s 361ms/step - loss: 0.0025
# Epoch 27/50
# 66/66 [==============================] - 23s 356ms/step - loss: 0.0024
# Epoch 28/50
# 66/66 [==============================] - 23s 348ms/step - loss: 0.0023
# Epoch 29/50
# 66/66 [==============================] - 23s 350ms/step - loss: 0.0026
# Epoch 30/50
# 66/66 [==============================] - 23s 354ms/step - loss: 0.0022
# Epoch 31/50
# 66/66 [==============================] - 23s 354ms/step - loss: 0.0023
# Epoch 32/50
# 66/66 [==============================] - 24s 358ms/step - loss: 0.0022
# Epoch 33/50
# 66/66 [==============================] - 24s 364ms/step - loss: 0.0023
# Epoch 34/50
# 66/66 [==============================] - 23s 354ms/step - loss: 0.0020
# Epoch 35/50
# 66/66 [==============================] - 24s 360ms/step - loss: 0.0022
# Epoch 36/50
# 66/66 [==============================] - 23s 355ms/step - loss: 0.0019
# Epoch 37/50
# 66/66 [==============================] - 22s 340ms/step - loss: 0.0019
# Epoch 38/50
# 66/66 [==============================] - 21s 319ms/step - loss: 0.0020
# Epoch 39/50
# 66/66 [==============================] - 21s 312ms/step - loss: 0.0021
# Epoch 40/50
# 66/66 [==============================] - 21s 322ms/step - loss: 0.0022
# Epoch 41/50
# 66/66 [==============================] - 21s 322ms/step - loss: 0.0021
# Epoch 42/50
# 66/66 [==============================] - 21s 324ms/step - loss: 0.0021
# Epoch 43/50
# 66/66 [==============================] - 21s 317ms/step - loss: 0.0019
# Epoch 44/50
# 66/66 [==============================] - 22s 327ms/step - loss: 0.0019
# Epoch 45/50
# 66/66 [==============================] - 22s 326ms/step - loss: 0.0019
# Epoch 46/50
# 66/66 [==============================] - 21s 326ms/step - loss: 0.0019
# Epoch 47/50
# 66/66 [==============================] - 21s 321ms/step - loss: 0.0020
# Epoch 48/50
# 66/66 [==============================] - 22s 328ms/step - loss: 0.0019
# Epoch 49/50
# 66/66 [==============================] - 21s 323ms/step - loss: 0.0019
# Epoch 50/50
# 66/66 [==============================] - 21s 318ms/step - loss: 0.0020

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pas_100_days = data_train.tail(100)

# %%
data_test = pd.concat([pas_100_days, data_test], ignore_index=True)

# %%
data_test_scale  =  scaler.fit_transform(data_test)

# %%
x = []
y = []

for i in range(100, data_test_scale.shape[0]):
    x.append(data_test_scale[i-100:i])
    y.append(data_test_scale[i,0])
x, y = np.array(x), np.array(y)

# %%
y_predict = model.predict(x)
# Out:
# 18/18 [==============================] - 4s 134ms/step

# %%
scale =1/scaler.scale_

# %%
y_predict = y_predict*scale

# %%
y = y*scale

# %%
plt.figure(figsize=(10,8))
plt.plot(y_predict, 'r', label = 'Predicted Price')
plt.plot(y, 'g', label = 'Original Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
model.save('Stock Predictions Model.keras')

# %%
model.save("model.h5")
# Out:
# C:\Users\Sneha\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
